# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# --- Load data ---
testdata2 = "GCZ2025_1Aug-13Nov2025.xlsx"
testdata1 = "GCG2026_1Dec2025-9Jan2026.xlsx"
df1 = pd.read_excel(testdata1)
df2 = pd.read_excel(testdata2)

# --- verify columns match ---
assert list(df1.columns) == list(df2.columns), "Column mismatch between files!"

# --- Combine (append rows) ---
combined_df = pd.concat([df1, df2], ignore_index=True)

# %%
# --- Filter for long entries only ---
df_long = combined_df[combined_df["Type"] == "Entry long"].copy()

# --- Ensure entry time is datetime ---
df_long["entry_time"] = pd.to_datetime(df_long["Date and time"])

# --- Extract hour of day ---
df_long["hour"] = df_long["entry_time"].dt.hour

# --- Classify win vs loss ---
df_long["result"] = df_long["Net P&L USD"].apply(lambda x: "Win" if x > 0 else "Loss")

# --- Aggregate counts by hour and result ---
distribution = (
    df_long
    .groupby(["hour", "result"])
    .size()
    .unstack(fill_value=0)
)

# --- Plot stacked bar chart ---
distribution.plot(
    kind="bar",
    stacked=True,
    figsize=(12, 6)
)

plt.title("Distribution of Winning vs Losing Long Trades by Entry Hour")
plt.xlabel("Entry Hour (24h)")
plt.ylabel("Number of Trades")
plt.legend(title="Trade Outcome")
plt.tight_layout()
plt.show()

# %%
# --- save all test data in one combined file ---
# output_path = "all_testdata.xlsx"
# combined_df.to_excel(output_path, index=False)

# %%
df_long.head(5)
# Out:
#    Trade #        Type     Date and time      Signal  Price USD  \
# 1        1  Entry long  2025-11-30 19:15  Entry Area     4258.3
# 3        2  Entry long  2025-11-30 19:47  Entry Area     4265.8
# 5        3  Entry long  2025-11-30 20:08  Entry Area     4258.1
# 7        4  Entry long  2025-11-30 22:15  Entry Area     4267.9
# 9        5  Entry long  2025-11-30 23:48  Entry Area     4278.5
#
#    Position size (qty)  Position size (value)  Net P&L USD  Net P&L %  \
# 1                    2                 851660         -720      -0.08
# 3                    2                 853160         -640      -0.08
# 5                    2                 851620         2300       0.27
# 7                    2                 853580         1600       0.19
# 9                    2                 855700         -620      -0.07
#
#    Favorable excursion USD  Favorable excursion %  Adverse excursion USD  \
# 1                      300                   0.04                   -720
# 3                       40                   0.00                   -640
# 5                     2300                   0.27                   -640
# 7                     1600                   0.19                   -120
# 9                      680                   0.08                   -620
#
#    Adverse excursion %  Cumulative P&L USD  Cumulative P&L %  \
# 1                -0.08                -720             -0.07
# 3                -0.08               -1360             -0.14
# 5                -0.08                 940              0.09
# 7                -0.01                2540              0.25
# 9                -0.07                1920              0.19
#
#            entry_time  hour result
# 1 2025-11-30 19:15:00    19   Loss
# 3 2025-11-30 19:47:00    19   Loss
# 5 2025-11-30 20:08:00    20    Win
# 7 2025-11-30 22:15:00    22    Win
# 9 2025-11-30 23:48:00    23   Loss

# %%
# --- look at the trades between 7-9am ET ---
# df_long.iloc[:,2].head()
df_long["Date and time"] = pd.to_datetime(df_long.iloc[:,2])

# %%
df_trades789 = df_long[
    (df_long.iloc[:, 1] == "Entry long") &
    (df_long["hour"].isin([7, 8, 9]))
]
df_trades789.head()
# Out:
#     Trade #        Type       Date and time      Signal  Price USD  \
# 25       13  Entry long 2025-12-01 07:41:00  Entry Area     4288.2
# 27       14  Entry long 2025-12-01 08:49:00  Entry Area     4292.5
# 29       15  Entry long 2025-12-01 09:38:00  Entry Area     4259.8
# 69       35  Entry long 2025-12-02 07:06:00  Entry Area     4237.3
# 71       36  Entry long 2025-12-02 08:09:00  Entry Area     4237.6
#
#     Position size (qty)  Position size (value)  Net P&L USD  Net P&L %  \
# 25                    2                 857640         -460      -0.05
# 27                    2                 858500          120       0.01
# 29                    2                 851960          320       0.04
# 69                    2                 847460         -540      -0.06
# 71                    2                 847520         -320      -0.04
#
#     Favorable excursion USD  Favorable excursion %  Adverse excursion USD  \
# 25                      280                   0.03                   -460
# 27                      180                   0.02                      0
# 29                     1400                   0.16                    -40
# 69                      200                   0.02                   -540
# 71                        0                   0.00                   -540
#
#     Adverse excursion %  Cumulative P&L USD  Cumulative P&L %  \
# 25                -0.05                6900              0.69
# 27                 0.00                7020              0.70
# 29                 0.00                7340              0.73
# 69                -0.06                3580              0.36
# 71                -0.06                3260              0.33
#
#             entry_time  hour result
# 25 2025-12-01 07:41:00     7   Loss
# 27 2025-12-01 08:49:00     8    Win
# 29 2025-12-01 09:38:00     9    Win
# 69 2025-12-02 07:06:00     7   Loss
# 71 2025-12-02 08:09:00     8   Loss

# %%
# --- normalize PnL 1250 and -500 ---
df_trades789_normPnL = df_trades789.copy()
df_trades789_normPnL.iloc[:,7] = np.where(
    df_trades789.iloc[:,7] > 0,
    1250, # winning trade 2.5RR
    -500 # losing trade
)

df_trades789_normPnL.head(20)
# Out:
#      Trade #        Type       Date and time      Signal  Price USD  \
# 25        13  Entry long 2025-12-01 07:41:00  Entry Area     4288.2
# 27        14  Entry long 2025-12-01 08:49:00  Entry Area     4292.5
# 29        15  Entry long 2025-12-01 09:38:00  Entry Area     4259.8
# 69        35  Entry long 2025-12-02 07:06:00  Entry Area     4237.3
# 71        36  Entry long 2025-12-02 08:09:00  Entry Area     4237.6
# 73        37  Entry long 2025-12-02 08:11:00  Entry Area     4236.7
# 75        38  Entry long 2025-12-02 08:44:00  Entry Area     4237.8
# 77        39  Entry long 2025-12-02 09:30:00  Entry Area     4256.9
# 79        40  Entry long 2025-12-02 09:43:00  Entry Area     4248.7
# 121       61  Entry long 2025-12-03 07:21:00  Entry Area     4235.6
# 123       62  Entry long 2025-12-03 09:08:00  Entry Area     4255.5
# 125       63  Entry long 2025-12-03 09:27:00  Entry Area     4258.0
# 127       64  Entry long 2025-12-03 09:55:00  Entry Area     4239.9
# 179       90  Entry long 2025-12-04 07:06:00  Entry Area     4224.3
# 181       91  Entry long 2025-12-04 08:31:00  Entry Area     4221.2
# 183       92  Entry long 2025-12-04 09:30:00  Entry Area     4236.8
# 185       93  Entry long 2025-12-04 09:41:00  Entry Area     4230.2
# 187       94  Entry long 2025-12-04 09:50:00  Entry Area     4230.9
# 219      110  Entry long 2025-12-05 07:19:00  Entry Area     4257.7
# 221      111  Entry long 2025-12-05 07:51:00  Entry Area     4255.6
#
#      Position size (qty)  Position size (value)  Net P&L USD  Net P&L %  \
# 25                     2                 857640         -500      -0.05
# 27                     2                 858500         1250       0.01
# 29                     2                 851960         1250       0.04
# 69                     2                 847460         -500      -0.06
# 71                     2                 847520         -500      -0.04
# 73                     2                 847340         -500      -0.04
# 75                     2                 847560         -500      -0.09
# 77                     2                 851380         -500      -0.08
# 79                     2                 849740         1250       0.17
# 121                    2                 847120         1250       0.14
# 123                    2                 851100         -500      -0.05
# 125                    2                 851600         1250       0.24
# 127                    2                 847980         1250       0.11
# 179                    2                 844860         1250       0.09
# 181                    2                 844240         -500      -0.02
# 183                    2                 847360         -500      -0.10
# 185                    2                 846040         -500      -0.05
# 187                    2                 846180         -500      -0.12
# 219                    2                 851540         -500      -0.08
# 221                    2                 851120         1250       0.11
#
#      Favorable excursion USD  Favorable excursion %  Adverse excursion USD  \
# 25                       280                   0.03                   -460
# 27                       180                   0.02                      0
# 29                      1400                   0.16                    -40
# 69                       200                   0.02                   -540
# 71                         0                   0.00                   -540
# 73                         0                   0.00                   -340
# 75                         0                   0.00                   -780
# 77                       920                   0.11                   -680
# 79                      1460                   0.17                   -520
# 121                     1180                   0.14                    -80
# 123                      220                   0.03                   -940
# 125                     2060                   0.24                   -600
# 127                      960                   0.11                   -640
# 179                      800                   0.09                      0
# 181                      520                   0.06                   -200
# 183                     1440                   0.17                   -880
# 185                        0                   0.00                   -540
# 187                     1440                   0.17                   -980
# 219                        0                   0.00                   -680
# 221                      960                   0.11                   -180
#
#      Adverse excursion %  Cumulative P&L USD  Cumulative P&L %  \
# 25                 -0.05                6900              0.69
# 27                  0.00                7020              0.70
# 29                  0.00                7340              0.73
# 69                 -0.06                3580              0.36
# 71                 -0.06                3260              0.33
# 73                 -0.04                2920              0.29
# 75                 -0.09                2140              0.21
# 77                 -0.08                1460              0.15
# 79                 -0.06                2920              0.29
# 121                -0.01               -1160             -0.12
# 123                -0.11               -1600             -0.16
# 125                -0.07                 460              0.05
# 127                -0.08                1420              0.14
# 179                 0.00                2520              0.25
# 181                -0.02                2320              0.23
# 183                -0.10                1440              0.14
# 185                -0.06                 980              0.10
# 187                -0.12                   0              0.00
# 219                -0.08                3800              0.38
# 221                -0.02                4760              0.48
#
#              entry_time  hour result
# 25  2025-12-01 07:41:00     7   Loss
# 27  2025-12-01 08:49:00     8    Win
# 29  2025-12-01 09:38:00     9    Win
# 69  2025-12-02 07:06:00     7   Loss
# 71  2025-12-02 08:09:00     8   Loss
# 73  2025-12-02 08:11:00     8   Loss
# 75  2025-12-02 08:44:00     8   Loss
# 77  2025-12-02 09:30:00     9   Loss
# 79  2025-12-02 09:43:00     9    Win
# 121 2025-12-03 07:21:00     7    Win
# 123 2025-12-03 09:08:00     9   Loss
# 125 2025-12-03 09:27:00     9    Win
# 127 2025-12-03 09:55:00     9    Win
# 179 2025-12-04 07:06:00     7    Win
# 181 2025-12-04 08:31:00     8   Loss
# 183 2025-12-04 09:30:00     9   Loss
# 185 2025-12-04 09:41:00     9   Loss
# 187 2025-12-04 09:50:00     9   Loss
# 219 2025-12-05 07:19:00     7   Loss
# 221 2025-12-05 07:51:00     7    Win

# %%
wins = (df_trades789_normPnL.iloc[:, 7] > 0).sum()
losses = (df_trades789_normPnL.iloc[:, 7] <= 0).sum()

print("wins ", wins, "losses ", losses)
# Out:
# wins  138 losses  246

# %%
win_rate = wins / (wins + losses)
print("win rate ", win_rate)
# Out:
# win rate  0.359375

# %%
print("total P/L ", sum(df_trades789_normPnL.iloc[:, 7]))
# Out:
# total P/L  49500

# %%
# --- Python Code: Cumulative P&L + Trailing Drawdown (Same Plot) ---

# %%
# --- P&L column (Column H) ---
pnl = df_trades789_normPnL.iloc[:, 7].reset_index(drop=True)

# --- Trade numbers ---
trade_number = range(1, len(pnl) + 1)

# --- Cumulative P&L ---
cum_pnl = pnl.cumsum()

# --- Trailing drawdown buffer logic ---
starting_dd = 6500
dd_buffer = []

current_dd = starting_dd

for trade_pnl in pnl:
    current_dd += trade_pnl          # add win or loss
    current_dd = min(current_dd, starting_dd)  # cap at 6500
    dd_buffer.append(current_dd)

dd_buffer = pd.Series(dd_buffer)

# --- Plot ---
plt.figure(figsize=(12, 6))

plt.plot(trade_number, cum_pnl, label="Cumulative P&L")
plt.plot(trade_number, dd_buffer, label="Remaining Drawdown Buffer")

plt.axhline(0, linestyle="--", linewidth=1)  # failure line

plt.xlabel("Trade Number")
plt.ylabel("Dollars")
plt.title("Cumulative P&L and Trailing Drawdown Buffer")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# --- lowest value of draw down ---
dd_buffer.min()
# Out:
# -2500
